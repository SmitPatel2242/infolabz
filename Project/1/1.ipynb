# %%
import pandas as pd

# %%
data = pd.read_csv("ipl_data_cleaned.csv")
data['final_total_runs']=0

total_runs = data.groupby(["id","innings"])["total_runs"].sum().reset_index()
for i, row in total_runs.iterrows():
    # find the corresponding rows in the main dataframe and update the final_total_runs column
    data.loc[(data['id'] == row['id']) & (data['innings'] == row['innings']), 'final_total_runs'] = row['total_runs']
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data = pd.read_csv("ipl_data_cleaned.csv")
#       2 data['final_total_runs']=0
#       4 total_runs = data.groupby(["id","innings"])["total_runs"].sum().reset_index()
#
# ...

# %%
# Let's group the dataframe by match_id and innings
grouped = data.groupby(["id", "innings"])

# Let's calculate the cumulative sum of wickets, runs, and balls
data["wickets"] = grouped["is_wkt_delivery"].cumsum()
data["runs"] = grouped["total_runs"].cumsum()
# df[['match_id','is_wicket','wickets','total_run', 'runs','over']].head(15)

# %%
data.to_csv('match_data.csv', index=False)
data = data[data["innings"]==1]
delete = ['id','season','innings','is_super_over','batter','non_striker','bowler','runs_off_bat','runs_from_extras','total_runs','is_wkt_delivery','player_out','wkt_type','fielders_involved','byes','legbyes','wides','noballs','penalty']
data = data.drop(delete,axis=1)
data = data[data["overs_balls"]>=5.0]

# %%
# Calculate the cumulative sum of 'total_runs' column until overs_balls reach 5.0 for each match
cumulative_sums = []
current_match_id = None
current_cumulative_sum = 0

for index, row in data.iterrows():
    if current_match_id != row['id']:
        current_match_id = row['id']
        current_cumulative_sum = 0
    
    if row['overs_balls'] <= 5.0:
        current_cumulative_sum += row['total_runs']
    else:
        current_cumulative_sum = 0  # Reset to 0 if overs_balls > 5.0
    
    cumulative_sums.append(current_cumulative_sum)

# Update the 'Total_1st_5_overs' column with the calculated cumulative sums
data['Total_1st_5_overs'] = cumulative_sums

# Save the modified DataFrame back to the CSV file
data.to_csv('data.csv', index=False)

# %%
encode_data = pd.get_dummies(data=data,columns=['batting_team','bowling_team'])
encode_data
# Out:
#                                    venue  overs_balls  final_total_runs  \
# 32      M Chinnaswamy Stadium, Bengaluru          5.1               222
# 33      M Chinnaswamy Stadium, Bengaluru          5.2               222
# 34      M Chinnaswamy Stadium, Bengaluru          5.3               222
# 35      M Chinnaswamy Stadium, Bengaluru          5.4               222
# 36      M Chinnaswamy Stadium, Bengaluru          5.5               222
# ...                                  ...          ...               ...
# 243718  Narendra Modi Stadium, Ahmedabad         19.2               214
# 243719  Narendra Modi Stadium, Ahmedabad         19.3               214
# 243720  Narendra Modi Stadium, Ahmedabad         19.4               214
# 243721  Narendra Modi Stadium, Ahmedabad         19.5               214
# 243722  Narendra Modi Stadium, Ahmedabad         19.6               214
#
#         wickets  runs  batting_team_Chennai Super Kings  \
# ...
